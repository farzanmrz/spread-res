# %% [markdown]
# # Get XLS Files BIFF Version with XLRD

# %%
import os
import xlrd
from collections import Counter

# Directory containing .xls files
data_dir = "../data/train_big"

# Dictionary to store counts of BIFF versions
biff_versions = Counter()

# Counter for files with no BIFF version information
no_version_files = 0

# List to log files causing warnings
warning_files = []

# Dictionary to track filenames for each non-BIFF8 version
non_biff8_files = {}

# Loop through each .xls file in the directory
for filename in os.listdir(data_dir):
    if filename.endswith(".xls"):  # Process only .xls files
        file_path = os.path.join(data_dir, filename)
        try:
            # Open the workbook using xlrd
            workbook = xlrd.open_workbook(file_path, on_demand=True)
            
            # Check for BIFF version
            version = workbook.biff_version
            
            # Increment the counter for this BIFF version
            biff_versions[version] += 1
            
            # Log filenames for non-BIFF8 versions
            if version != 80:  # BIFF8 corresponds to 80
                if version not in non_biff8_files:
                    non_biff8_files[version] = []
                non_biff8_files[version].append(filename)
        except Exception as e:
            # Log the file that caused the exception
            no_version_files += 1
            warning_files.append((filename, str(e)))  # Save file name and exception
        finally:
            # Close the workbook if opened
            if 'workbook' in locals():
                workbook.release_resources()

# Print metrics
print("BIFF Version Counts:")
for version, count in biff_versions.items():
    print(f"  BIFF{version // 10}: {count} files")  # Format BIFF version

print(f"\nFiles with no BIFF version information: {no_version_files}")

if warning_files:
    print("\nFiles causing warnings:")
    for file, warning in warning_files:
        print(f"  {file}: {warning}")

if non_biff8_files:
    print("\nFiles with Non-BIFF8 Formats:")
    for version, files in non_biff8_files.items():
        print(f"\n  BIFF{version // 10}:")
        for file in files:
            print(f"    {file}")
# Out:
# *** WARNING: on_demand is not supported for this Excel version.
# *** Setting on_demand to False.
# *** WARNING: on_demand is not supported for this Excel version.
# *** Setting on_demand to False.
# *** WARNING: on_demand is not supported for this Excel version.
# *** Setting on_demand to False.
# BIFF Version Counts:
#   BIFF8: 392 files
#   BIFF7: 11 files
#   BIFF4: 3 files
#   BIFF5: 3 files
#
# Files with no BIFF version information: 0
#
# Files with Non-BIFF8 Formats:
#
#   BIFF7:
#     mark_taylor_000_1_1.pst.91.xls
#     darrell_schoolcraft_000_1_1_1.pst.533.xls
#     sara_shackleton_000_1_2.pst.239.xls
#     lindy_donoho_000_1_1_1.pst.110.xls
#     sara_shackleton_000_1_1_1.pst.53.xls
#     theresa_staab_000_1_1.pst.104.xls
#     sara_shackleton_000_1_1_1.pst.54.xls
#     shelley_corman_000_1_1.pst.55.xls
#     richard_sanders_001_1_1_1.pst.11.xls
#     david_delainey_000_1_1_1.pst.20.xls
#     mark_taylor_000_1_1.pst.174.xls
#
#   BIFF4:
#     shelley_corman_000_1_1.pst.28.xls
#     dutch_quigley_000_1_1.pst.213.xls
#     benjamin_rogers_000_1_1.pst.72.xls
#
#   BIFF5:
#     kevin_hyatt_000_1_1.pst.62.xls
#     benjamin_rogers_000_1_1.pst.71.xls
#     dutch_quigley_000_1_1.pst.1.xls

# %% [markdown]
# ## Count Total Files in a Directory

# %%
import os

# Directory path
data_dir = "../data/enron_clean"

# Count the total number of files
total_files = len([file for file in os.listdir(data_dir) if os.path.isfile(os.path.join(data_dir, file))])

# Print the total count
print(f"Total number of files in '{data_dir}': {total_files}")
# Out:
# Total number of files in '../data/enron_clean': 945

# %% [markdown]
# ## List Files in a Directory with Recursive Search

# %%
import os

# Define the relative path to the target directory
target_directory = '../data2/'

# Initialize a dictionary to store subdirectory names and file counts
subdirectory_file_counts = {}

# Walk through the target directory and its subdirectories
for root, dirs, files in os.walk(target_directory):
    # Skip the top-level directory itself (if needed)
    if root == target_directory:
        continue
    
    # Get the name of the current subdirectory
    subdirectory_name = os.path.basename(root)
    
    # Count the number of files in the current subdirectory
    file_count = len(files)
    
    # Store the subdirectory name and file count in the dictionary
    subdirectory_file_counts[subdirectory_name] = file_count

# Sort the dictionary by subdirectory name in ascending order
sorted_file_counts = sorted(subdirectory_file_counts.items())

# Display the sorted results
for subdirectory, count in sorted_file_counts:
    print(f"{subdirectory}: {count} files")
# Out:
# .ipynb_checkpoints: 1 files
# csv: 2 files
# enron: 1253 files
# enron (1): 624 files
# enron_clean: 945 files
# infer_small: 4 files
# massive: 3 files
# one_bold_small: 10 files
# test: 2 files
# test_big: 283 files
# test_big (1): 183 files
# test_big (2): 100 files
# test_medium: 173 files
# test_medium (1): 50 files
# test_micro: 23 files
# test_micro (1): 6 files
# test_small: 92 files
# test_small (1): 25 files
# test_teeny: 3 files
# test_tiny: 12 files
# train2: 871 files
# train_big: 799 files
# train_double: 1247 files
# train_medium: 1196 files
# train_medium (1): 400 files
# train_micro: 159 files
# train_micro (1): 50 files
# train_small: 634 files
# train_small (1): 200 files
# train_teeny: 25 files
# train_tiny: 100 files
# val_big: 312 files
# val_big (1): 212 files
# val_big (2): 100 files
# val_medium: 187 files
# val_medium (1): 50 files
# val_micro: 22 files
# val_micro (1): 6 files
# val_small: 93 files
# val_small (1): 25 files
# val_teeny: 3 files
# val_tiny: 12 files

# %% [markdown]
# # Clean Directories for Duplicates
#
# big (800/100/100) > medium (400/50/50) > small (200/25/25) > tiny (100/12/12) > micro (50/6/6) > teeny (25/3/3)

# %%
import os

# Define the relative path to the target directory
target_directory = '../data2/val_teeny'

# Walk through the target directory and its subdirectories
for root, dirs, files in os.walk(target_directory):
    # Iterate through all files in the current directory
    for file_name in files:
        # Check if the file ends with '(1)'
        if file_name.endswith('(1).xlsx'):
            # Generate the corresponding non-duplicate file name
            base_name_with_ext = file_name.replace('(1)', '').strip()
            
            # Normalize file names for comparison
            base_name_normalized = os.path.normcase(base_name_with_ext)
            
            # Check if the non-duplicate file exists in the same directory
            if any(os.path.normcase(f) == base_name_normalized for f in files):
                # Generate the full path of the duplicate file
                duplicate_file_path = os.path.join(root, file_name)
                
                # Delete the duplicate file
                os.remove(duplicate_file_path)
                print(f"Deleted duplicate: {duplicate_file_path}")
            else:
                print(f"Original file not found for: {file_name}")

# Initialize a counter for the total number of files
file_count = 0

# List all remaining files for debugging purposes
print("\nRemaining files in the directory:")
for root, dirs, files in os.walk(target_directory):
    for file_name in files:
        # Print each file's full path
        file_path = os.path.join(root, file_name)
        print(file_path)
        # Increment the file counter
        file_count += 1

# Print the total number of files
print(f"\nTotal number of files in '{target_directory}': {file_count}")
# Out:
# Deleted duplicate: ../data2/val_teeny/Table1-d_far(1).xlsx
# Original file not found for: Results_2520Sheet_2520Test_25203_2520WRR(1).xlsx
# Original file not found for: 40_2520Lakes_2520Central_2520UnmixO_2520SciHub_2520-_2520Published(1).xlsx
#
# Remaining files in the directory:
# ../data2/val_teeny/40%2520Lakes%2520Central%2520UnmixO%2520SciHub%2520-%2520Published.xlsx
# ../data2/val_teeny/Results%2520Sheet%2520Test%25203%2520WRR.xlsx
# ../data2/val_teeny/Results_2520Sheet_2520Test_25203_2520WRR(1).xlsx
# ../data2/val_teeny/40_2520Lakes_2520Central_2520UnmixO_2520SciHub_2520-_2520Published(1).xlsx
# ../data2/val_teeny/Table1-d_far.xlsx
#
# Total number of files in '../data2/val_teeny': 5

# %% [markdown]
# List count of files
#
# big (800/100/100) > medium (400/50/50) > small (200/25/25) > tiny (100/12/12) > micro (50/6/6) > teeny (25/3/3)

# %%
import os

# Define the directories to count files in
directories = [
    '../data2/enron',
    '../data2/enron_clean',
]

# Iterate through the directories
for directory in directories:
    # Initialize a counter for the total number of files
    file_count = 0
    
    # Check if the directory exists
    if os.path.exists(directory):
        # Walk through the directory and its subdirectories
        for root, dirs, files in os.walk(directory):
            file_count += len(files)  # Count the files in the current directory
    else:
        print(f"Directory '{directory}' does not exist.")
        continue
    
    # Print the total number of files for this directory
    print(f"Total number of files in '{directory}': {file_count}")
# Out:
# Total number of files in '../data2/enron': 624
# Total number of files in '../data2/enron_clean': 478

# %%
import os

# Define the directories to count files in
directories = [
    '../data2/val_big',
    '../data2/test_big',
    '../data2/train_big'
]

# Iterate through the directories
for directory in directories:
    # Initialize a counter for the total number of files
    file_count = 0
    
    # Check if the directory exists
    if os.path.exists(directory):
        # Walk through the directory and its subdirectories
        for root, dirs, files in os.walk(directory):
            file_count += len(files)  # Count the files in the current directory
    else:
        print(f"Directory '{directory}' does not exist.")
        continue
    
    # Print the total number of files for this directory
    print(f"Total number of files in '{directory}': {file_count}")
# Out:
# Total number of files in '../data2/val_big': 100
# Total number of files in '../data2/test_big': 100
# Total number of files in '../data2/train_big': 799

# %%
import os

# Define the directory containing the duplicates
target_directory = '../data2/enron_clean'

# Walk through the target directory
for root, dirs, files in os.walk(target_directory):
    for file_name in files:
        # Check if the file ends with '(1).xls'
        if file_name.endswith('(1).xls'):
            # Generate the corresponding non-duplicate file name
            original_file_name = file_name.replace('(1)', '').strip()
            
            # Check if the non-duplicate version exists in the same directory
            if original_file_name in files:
                # Generate the full path of the duplicate file
                duplicate_file_path = os.path.join(root, file_name)
                
                # Delete the duplicate file
                os.remove(duplicate_file_path)
                print(f"Deleted duplicate: {duplicate_file_path}")
            else:
                print(f"No original found for: {file_name}")
# Out:
# Deleted duplicate: ../data2/enron_clean/cara_semperger_000_1_1.pst.40(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.778(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.523(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.705(1).xls
# Deleted duplicate: ../data2/enron_clean/teb_lokey_000_1_1.pst.18(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.211(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.766(1).xls
# Deleted duplicate: ../data2/enron_clean/tracy_geaccone_000_1_1.pst.269(1).xls
# Deleted duplicate: ../data2/enron_clean/james_steffes_000_1_1.pst.165(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_ring_000_1_1.pst.163(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.802(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.431(1).xls
# Deleted duplicate: ../data2/enron_clean/chris_stokley_000_1_1.pst.173(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.774(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.452(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_ring_000_1_1.pst.171(1).xls
# Deleted duplicate: ../data2/enron_clean/sara_shackleton_003_1_1.pst.77(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.949(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_ring_000_1_1.pst.93(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.834(1).xls
# Deleted duplicate: ../data2/enron_clean/john_hodge_000_1_1.pst.105(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.156(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_002_1_1_1.pst.199(1).xls
# Deleted duplicate: ../data2/enron_clean/paul_y_barbo_000_1_1.pst.130(1).xls
# Deleted duplicate: ../data2/enron_clean/michelle_lokay_000_1_2_1.pst.149(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.348(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.339(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_002_1_1_1.pst.322(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_sanders_001_1_1_1.pst.0(1).xls
# Deleted duplicate: ../data2/enron_clean/kim_ward_000_1_2.pst.109(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.244(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.826(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_000_1_1_1.pst.321(1).xls
# Deleted duplicate: ../data2/enron_clean/drew_fossum_000_1_1.pst.295(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.259(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.224(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.687(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.716(1).xls
# Deleted duplicate: ../data2/enron_clean/jeffrey_a_shankman_000_1_2.pst.131(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.147(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.787(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.293(1).xls
# Deleted duplicate: ../data2/enron_clean/theresa_staab_000_1_1.pst.155(1).xls
# Deleted duplicate: ../data2/enron_clean/shelley_corman_000_1_1.pst.55(1).xls
# Deleted duplicate: ../data2/enron_clean/shelley_corman_000_1_1.pst.28(1).xls
# Deleted duplicate: ../data2/enron_clean/james_steffes_000_1_1.pst.221(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.181(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.695(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.381(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.136(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_sanders_000_1_2.pst.14(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_shapiro_000_1_1.pst.177(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_002_1_1_1.pst.150(1).xls
# Deleted duplicate: ../data2/enron_clean/sara_shackleton_001_1_1.pst.372(1).xls
# Deleted duplicate: ../data2/enron_clean/lindy_donoho_000_1_1_1.pst.113(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_ring_000_1_1.pst.72(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_002_1_1_1.pst.166(1).xls
# Deleted duplicate: ../data2/enron_clean/dutch_quigley_000_1_1.pst.213(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.312(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_sanders_000_1_1_1.pst.42(1).xls
# Deleted duplicate: ../data2/enron_clean/louise_kitchen_001_1_1_1.pst.345(1).xls
# Deleted duplicate: ../data2/enron_clean/shelley_corman_000_1_1.pst.63(1).xls
# Deleted duplicate: ../data2/enron_clean/sara_shackleton_001_1_1.pst.346(1).xls
# Deleted duplicate: ../data2/enron_clean/michelle_lokay_000_1_2_1.pst.235(1).xls
# Deleted duplicate: ../data2/enron_clean/larry_campbell_000_1_1.pst.225(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.383(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_002_1_1_1.pst.152(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.689(1).xls
# Deleted duplicate: ../data2/enron_clean/tracy_geaccone_000_1_1.pst.152(1).xls
# Deleted duplicate: ../data2/enron_clean/david_delainey_000_1_1_1.pst.20(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.697(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.291(1).xls
# Deleted duplicate: ../data2/enron_clean/shelley_corman_000_1_1.pst.57(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.391(1).xls
# Deleted duplicate: ../data2/enron_clean/input(1).xls
# Deleted duplicate: ../data2/enron_clean/theresa_staab_000_1_1.pst.149(1).xls
# Deleted duplicate: ../data2/enron_clean/larry_campbell_000_1_1.pst.229(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.685(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.145(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.326(1).xls
# Deleted duplicate: ../data2/enron_clean/shelley_corman_000_1_1.pst.61(1).xls
# Deleted duplicate: ../data2/enron_clean/danny_mccarty_000_1_1.pst.10(1).xls
# Deleted duplicate: ../data2/enron_clean/james_steffes_000_1_1.pst.207(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.310(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.173(1).xls
# Deleted duplicate: ../data2/enron_clean/kimberly_watson_000_1_1.pst.76(1).xls
# Deleted duplicate: ../data2/enron_clean/lindy_donoho_000_1_1_1.pst.111(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_002_1_1_1.pst.164(1).xls
# Deleted duplicate: ../data2/enron_clean/elizabeth_sager_000_1_1.pst.164(1).xls
# Deleted duplicate: ../data2/enron_clean/diana_scholtes_000_1_1.pst.3(1).xls
# Deleted duplicate: ../data2/enron_clean/don_baughman_000_1_1.pst.224(1).xls
# Deleted duplicate: ../data2/enron_clean/kimberly_watson_000_1_1.pst.115(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_ring_000_1_1.pst.173(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.533(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.800(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.170(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.442(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.764(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.707(1).xls
# Deleted duplicate: ../data2/enron_clean/dan_hyvl_000_1_1.pst.131(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.225(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.752(1).xls
# Deleted duplicate: ../data2/enron_clean/sara_shackleton_000_1_1_1.pst.97(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.947(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.1004(1).xls
# Deleted duplicate: ../data2/enron_clean/paul_lucci_000_1_1.pst.29(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.258(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.409(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_000_1_1_1.pst.323(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_ring_000_1_1.pst.157(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.824(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.292(1).xls
# Deleted duplicate: ../data2/enron_clean/daren_farmer_000_1_1.pst.108(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.466(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.955(1).xls
# Deleted duplicate: ../data2/enron_clean/gerald_nemec_000_1_1.pst.153(1).xls
# Deleted duplicate: ../data2/enron_clean/tracy_geaccone_000_1_1.pst.185(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.828(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.578(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.280(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.836(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.254(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_sanders_000_1_1_1.pst.48(1).xls
# Deleted duplicate: ../data2/enron_clean/lindy_donoho_000_1_1_1.pst.115(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_sanders_001_1_1_1.pst.11(1).xls
# Deleted duplicate: ../data2/enron_clean/louise_kitchen_000_1_1_1_1.pst.211(1).xls
# Deleted duplicate: ../data2/enron_clean/james_steffes_000_1_1.pst.211(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_ring_000_1_1.pst.66(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.277(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_sanders_000_1_1_1.pst.44(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.591(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.269(1).xls
# Deleted duplicate: ../data2/enron_clean/jeffrey_a_shankman_000_1_2.pst.129(1).xls
# Deleted duplicate: ../data2/enron_clean/sara_shackleton_000_1_2.pst.96(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.395(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.710(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.781(1).xls
# Deleted duplicate: ../data2/enron_clean/bill_williams_iii_000_1_1.pst.93(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.998(1).xls
# Deleted duplicate: ../data2/enron_clean/mark_taylor_000_1_1.pst.91(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_sanders_000_1_2.pst.12(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_sanders_000_1_2.pst.109(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.693(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.702(1).xls
# Deleted duplicate: ../data2/enron_clean/kimberly_watson_000_1_1.pst.27(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.187(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.399(1).xls
# Deleted duplicate: ../data2/enron_clean/gerald_nemec_000_1_1.pst.157(1).xls
# Deleted duplicate: ../data2/enron_clean/john_hodge_000_1_1.pst.103(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.951(1).xls
# Deleted duplicate: ../data2/enron_clean/john_hodge_000_1_1.pst.160(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.932(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.832(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.350(1).xls
# Deleted duplicate: ../data2/enron_clean/daren_farmer_000_1_1.pst.112(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_000_1_1_1.pst.327(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.221(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.756(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.196(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.470(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.943(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.1000(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.296(1).xls
# Deleted duplicate: ../data2/enron_clean/parse_input(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.975(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.525(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.703(1).xls
# Deleted duplicate: ../data2/enron_clean/sara_shackleton_000_1_2.pst.121(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.117(1).xls
# Deleted duplicate: ../data2/enron_clean/kevin_hyatt_000_1_1.pst.56(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.429(1).xls
# Deleted duplicate: ../data2/enron_clean/kevin_hyatt_000_1_1.pst.27(1).xls
# Deleted duplicate: ../data2/enron_clean/don_baughman_000_1_1.pst.220(1).xls
# Deleted duplicate: ../data2/enron_clean/jeff_dasovich_000_1_1_1.pst.27(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.772(1).xls
# Deleted duplicate: ../data2/enron_clean/michelle_lokay_000_1_2_1.pst.823(1).xls
# Deleted duplicate: ../data2/enron_clean/jeffrey_a_shankman_000_1_2.pst.210(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.979(1).xls
# Deleted duplicate: ../data2/enron_clean/gerald_nemec_000_1_1.pst.159(1).xls
# Deleted duplicate: ../data2/enron_clean/john_hodge_000_1_1.pst.29(1).xls
# Deleted duplicate: ../data2/enron_clean/kevin_hyatt_000_1_1.pst.62(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_ring_000_1_1.pst.85(1).xls
# Deleted duplicate: ../data2/enron_clean/don_baughman_000_1_1.pst.218(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_sanders_001_1_1_1.pst.4(1).xls
# Deleted duplicate: ../data2/enron_clean/lynn_blair_000_1_1.pst.173(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.1002(1).xls
# Deleted duplicate: ../data2/enron_clean/paul_y_barbo_000_1_1.pst.126(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.754(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.472(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.403(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.352(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.930(1).xls
# Deleted duplicate: ../data2/enron_clean/sara_shackleton_000_1_2.pst.107(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.830(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.758(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.198(1).xls
# Deleted duplicate: ../data2/enron_clean/phillip_platter_000_1_1.pst.60(1).xls
# Deleted duplicate: ../data2/enron_clean/jeff_dasovich_000_1_1_1.pst.128(1).xls
# Deleted duplicate: ../data2/enron_clean/sara_shackleton_000_1_2.pst.119(1).xls
# Deleted duplicate: ../data2/enron_clean/gerald_nemec_000_1_1.pst.155(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_ring_000_1_1.pst.89(1).xls
# Deleted duplicate: ../data2/enron_clean/daren_farmer_000_1_1.pst.1198(1).xls
# Deleted duplicate: ../data2/enron_clean/don_baughman_000_1_1.pst.241(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.806(1).xls
# Deleted duplicate: ../data2/enron_clean/gerald_nemec_000_1_1.pst.163(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.770(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.307(1).xls
# Deleted duplicate: ../data2/enron_clean/sara_shackleton_000_1_2.pst.123(1).xls
# Deleted duplicate: ../data2/enron_clean/lindy_donoho_000_1_1_1.pst.18(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.701(1).xls
# Deleted duplicate: ../data2/enron_clean/jeff_dasovich_000_1_1_1.pst.29(1).xls
# Deleted duplicate: ../data2/enron_clean/kevin_hyatt_000_1_1.pst.54(1).xls
# Deleted duplicate: ../data2/enron_clean/james_steffes_000_1_1.pst.161(1).xls
# Deleted duplicate: ../data2/enron_clean/tracy_geaccone_000_1_1.pst.210(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.544(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.762(1).xls
# Deleted duplicate: ../data2/enron_clean/lynn_blair_000_1_1.pst.145(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.593(1).xls
# Deleted duplicate: ../data2/enron_clean/theresa_staab_000_1_1.pst.104(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.316(1).xls
# Deleted duplicate: ../data2/enron_clean/paul_y_barbo_000_1_1.pst.53(1).xls
# Deleted duplicate: ../data2/enron_clean/lindy_donoho_000_1_1_1.pst.105(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.204(1).xls
# Deleted duplicate: ../data2/enron_clean/michelle_lokay_000_1_2_1.pst.780(1).xls
# Deleted duplicate: ../data2/enron_clean/brad_mckay_000_1_1.pst.12(1).xls
# Deleted duplicate: ../data2/enron_clean/louise_kitchen_001_1_1_1.pst.60(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_002_1_1_1.pst.162(1).xls
# Deleted duplicate: ../data2/enron_clean/kimberly_watson_000_1_1.pst.70(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_sanders_000_1_2.pst.26(1).xls
# Deleted duplicate: ../data2/enron_clean/sara_shackleton_000_1_1_1.pst.54(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.691(1).xls
# Deleted duplicate: ../data2/enron_clean/brad_mckay_000_1_1.pst.24(1).xls
# Deleted duplicate: ../data2/enron_clean/jeffrey_a_shankman_000_1_2.pst.139(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_002_1_1_1.pst.154(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_002_1_1_1.pst.158(1).xls
# Deleted duplicate: ../data2/enron_clean/benjamin_rogers_000_1_1.pst.71(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.612(1).xls
# Deleted duplicate: ../data2/enron_clean/louise_kitchen_001_1_1_1.pst.369(1).xls
# Deleted duplicate: ../data2/enron_clean/larry_campbell_000_1_1.pst.231(1).xls
# Deleted duplicate: ../data2/enron_clean/lindy_donoho_000_1_1_1.pst.133(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_002_1_1_1.pst.167(1).xls
# Deleted duplicate: ../data2/enron_clean/lindy_donoho_000_1_1_1.pst.112(1).xls
# Deleted duplicate: ../data2/enron_clean/shelley_corman_000_1_1.pst.70(1).xls
# Deleted duplicate: ../data2/enron_clean/fletcher_sturm_000_1_1.pst.107(1).xls
# Deleted duplicate: ../data2/enron_clean/michelle_lokay_000_1_2_1.pst.263(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.201(1).xls
# Deleted duplicate: ../data2/enron_clean/louise_kitchen_000_1_1_1_1.pst.316(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.270(1).xls
# Deleted duplicate: ../data2/enron_clean/kimberly_watson_000_1_1.pst.67(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.213(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_sanders_000_1_1_1.pst.43(1).xls
# Deleted duplicate: ../data2/enron_clean/mark_taylor_000_1_1.pst.174(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_002_1_1_1.pst.143(1).xls
# Deleted duplicate: ../data2/enron_clean/theresa_staab_000_1_1.pst.154(1).xls
# Deleted duplicate: ../data2/enron_clean/sara_shackleton_000_1_1_1.pst.20(1).xls
# Deleted duplicate: ../data2/enron_clean/kevin_hyatt_000_1_1.pst.156(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.292(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.192(1).xls
# Deleted duplicate: ../data2/enron_clean/john_hodge_000_1_1.pst.98(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.146(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.686(1).xls
# Deleted duplicate: ../data2/enron_clean/jim_schwieger_000_1_1.pst.106(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.229(1).xls
# Deleted duplicate: ../data2/enron_clean/kevin_hyatt_000_1_1.pst.144(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_sanders_000_1_2.pst.15(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.380(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.180(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.981(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.694(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.794(1).xls
# Deleted duplicate: ../data2/enron_clean/james_steffes_000_1_1.pst.220(1).xls
# Deleted duplicate: ../data2/enron_clean/michelle_lokay_000_1_2_1.pst.764(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.257(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.835(1).xls
# Deleted duplicate: ../data2/enron_clean/kimberly_watson_000_1_1.pst.94(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.948(1).xls
# Deleted duplicate: ../data2/enron_clean/phillip_platter_000_1_1.pst.65(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_000_1_1_1.pst.320(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.944(1).xls
# Deleted duplicate: ../data2/enron_clean/lindy_donoho_000_1_1_1.pst.182(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.514(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.245(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.163(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.827(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.469(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.338(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_sanders_001_1_1_1.pst.1(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.173(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.704(1).xls
# Deleted duplicate: ../data2/enron_clean/kevin_hyatt_000_1_1.pst.51(1).xls
# Deleted duplicate: ../data2/enron_clean/cara_semperger_000_1_1.pst.41(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.708(1).xls
# Deleted duplicate: ../data2/enron_clean/kimberly_watson_000_1_1.pst.116(1).xls
# Deleted duplicate: ../data2/enron_clean/lynn_blair_000_1_1.pst.152(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.161(1).xls
# Deleted duplicate: ../data2/enron_clean/elizabeth_sager_000_1_1.pst.52(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.430(1).xls
# Deleted duplicate: ../data2/enron_clean/tracy_geaccone_000_1_1.pst.264(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.825(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_sanders_001_1_1_1.pst.3(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.159(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_ring_000_1_1.pst.156(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.946(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.837(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_ring_000_1_1.pst.90(1).xls
# Deleted duplicate: ../data2/enron_clean/michelle_lokay_000_1_2_1.pst.129(1).xls
# Deleted duplicate: ../data2/enron_clean/lynn_blair_000_1_1.pst.56(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.829(1).xls
# Deleted duplicate: ../data2/enron_clean/tracy_geaccone_000_1_1.pst.184(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.929(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.432(1).xls
# Deleted duplicate: ../data2/enron_clean/john_hodge_000_1_1.pst.14(1).xls
# Deleted duplicate: ../data2/enron_clean/kimberly_watson_000_1_1.pst.114(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.706(1).xls
# Deleted duplicate: ../data2/enron_clean/dan_hyvl_000_1_1.pst.130(1).xls
# Deleted duplicate: ../data2/enron_clean/lynn_blair_000_1_1.pst.121(1).xls
# Deleted duplicate: ../data2/enron_clean/sara_shackleton_003_1_1.pst.50(1).xls
# Deleted duplicate: ../data2/enron_clean/kevin_hyatt_000_1_1.pst.53(1).xls
# Deleted duplicate: ../data2/enron_clean/james_steffes_000_1_1.pst.166(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.443(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.543(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_sanders_000_1_1_1.pst.41(1).xls
# Deleted duplicate: ../data2/enron_clean/jim_schwieger_000_1_1.pst.96(1).xls
# Deleted duplicate: ../data2/enron_clean/chris_germany_000_1_2.pst.1016(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.172(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.594(1).xls
# Deleted duplicate: ../data2/enron_clean/sara_shackleton_000_1_2.pst.239(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_002_1_1_1.pst.177(1).xls
# Deleted duplicate: ../data2/enron_clean/lindy_donoho_000_1_1_1.pst.102(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.303(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_sanders_000_1_1_1.pst.53(1).xls
# Deleted duplicate: ../data2/enron_clean/louise_kitchen_000_1_1_1_1.pst.277(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_ring_000_1_1.pst.71(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_002_1_1_1.pst.165(1).xls
# Deleted duplicate: ../data2/enron_clean/lindy_donoho_000_1_1_1.pst.110(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.696(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_000_1_1_1.pst.51(1).xls
# Deleted duplicate: ../data2/enron_clean/sara_shackleton_000_1_1_1.pst.53(1).xls
# Deleted duplicate: ../data2/enron_clean/james_steffes_000_1_1.pst.222(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_002_1_1_1.pst.153(1).xls
# Deleted duplicate: ../data2/enron_clean/john_hodge_000_1_1.pst.96(1).xls
# Deleted duplicate: ../data2/enron_clean/louise_kitchen_001_1_1_1.pst.362(1).xls
# Deleted duplicate: ../data2/enron_clean/kevin_hyatt_000_1_1.pst.146(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.282(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.382(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.144(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.784(1).xls
# Deleted duplicate: ../data2/enron_clean/sara_shackleton_001_1_1.pst.336(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.327(1).xls
# Deleted duplicate: ../data2/enron_clean/lindy_donoho_000_1_1_1.pst.134(1).xls
# Deleted duplicate: ../data2/enron_clean/theresa_staab_000_1_1.pst.156(1).xls
# Deleted duplicate: ../data2/enron_clean/kevin_hyatt_000_1_1.pst.154(1).xls
# Deleted duplicate: ../data2/enron_clean/gerald_nemec_000_1_1.pst.111(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_sanders_001_1_2.pst.137(1).xls
# Deleted duplicate: ../data2/enron_clean/lynn_blair_000_1_1.pst.158(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.702(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.524(1).xls
# Deleted duplicate: ../data2/enron_clean/marie_heard_000_1_1.pst.35(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_000_1_1_1.pst.310(1).xls
# Deleted duplicate: ../data2/enron_clean/gerald_nemec_000_1_1.pst.103(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.978(1).xls
# Deleted duplicate: ../data2/enron_clean/daren_farmer_001_1_1.pst.1216(1).xls
# Deleted duplicate: ../data2/enron_clean/jeffrey_a_shankman_000_1_2.pst.211(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_ring_000_1_1.pst.168(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.167(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.304(1).xls
# Deleted duplicate: ../data2/enron_clean/phillip_platter_000_1_1.pst.63(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.833(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.285(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.950(1).xls
# Deleted duplicate: ../data2/enron_clean/kim_ward_000_1_2.pst.102(1).xls
# Deleted duplicate: ../data2/enron_clean/lindy_donoho_000_1_1_1.pst.21(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_sanders_001_1_1_1.pst.7(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.297(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.243(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.165(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.197(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.471(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.289(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_000_1_1_1.pst.326(1).xls
# Deleted duplicate: ../data2/enron_clean/jeffrey_a_shankman_000_1_2.pst.136(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.780(1).xls
# Deleted duplicate: ../data2/enron_clean/benjamin_rogers_000_1_1.pst.72(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.323(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.294(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_002_1_1_1.pst.145(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.398(1).xls
# Deleted duplicate: ../data2/enron_clean/james_steffes_000_1_1.pst.226(1).xls
# Deleted duplicate: ../data2/enron_clean/bill_williams_iii_000_1_1.pst.80(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.692(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.331(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_002_1_1_1.pst.149(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.186(1).xls
# Deleted duplicate: ../data2/enron_clean/kevin_hyatt_000_1_1.pst.142(1).xls
# Deleted duplicate: ../data2/enron_clean/dutch_quigley_000_1_1.pst.199(1).xls
# Deleted duplicate: ../data2/enron_clean/shelley_corman_000_1_1.pst.40(1).xls
# Deleted duplicate: ../data2/enron_clean/jim_schwieger_000_1_1.pst.100(1).xls
# Deleted duplicate: ../data2/enron_clean/elizabeth_sager_000_1_1.pst.161(1).xls
# Deleted duplicate: ../data2/enron_clean/brad_mckay_000_1_1.pst.11(1).xls
# Deleted duplicate: ../data2/enron_clean/james_steffes_000_1_1.pst.210(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_sanders_001_1_1_1.pst.10(1).xls
# Deleted duplicate: ../data2/enron_clean/lindy_donoho_000_1_1_1.pst.114(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_002_1_1_1.pst.161(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.215(1).xls
# Deleted duplicate: ../data2/enron_clean/dutch_quigley_000_1_1.pst.1(1).xls
# Deleted duplicate: ../data2/enron_clean/shelley_corman_000_1_1.pst.42(1).xls
# Deleted duplicate: ../data2/enron_clean/lynn_blair_000_1_1.pst.99(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_002_1_1_1.pst.155(1).xls
# Deleted duplicate: ../data2/enron_clean/lindy_donoho_000_1_1_1.pst.143(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.233(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.690(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.790(1).xls
# Deleted duplicate: ../data2/enron_clean/shelley_corman_000_1_1.pst.50(1).xls
# Deleted duplicate: ../data2/enron_clean/tracy_geaccone_000_1_1.pst.147(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_sanders_001_1_2.pst.91(1).xls
# Deleted duplicate: ../data2/enron_clean/dutch_quigley_000_1_1.pst.197(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.221(1).xls
# Deleted duplicate: ../data2/enron_clean/michelle_lokay_000_1_2_1.pst.243(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.196(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.321(1).xls
# Deleted duplicate: ../data2/enron_clean/jeffrey_a_shankman_000_1_2.pst.134(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.613(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.109(1).xls
# Deleted duplicate: ../data2/enron_clean/jonathan_mckay_001_1_1.pst.114(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.174(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.725(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.592(1).xls
# Deleted duplicate: ../data2/enron_clean/lindy_donoho_000_1_1_1.pst.116(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.266(1).xls
# Deleted duplicate: ../data2/enron_clean/louise_kitchen_001_1_1_1.pst.61(1).xls
# Deleted duplicate: ../data2/enron_clean/kevin_hyatt_000_1_1.pst.168(1).xls
# Deleted duplicate: ../data2/enron_clean/james_steffes_000_1_1.pst.212(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.306(1).xls
# Deleted duplicate: ../data2/enron_clean/kevin_hyatt_000_1_1.pst.24(1).xls
# Deleted duplicate: ../data2/enron_clean/paul_lucci_000_1_1.pst.6(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.545(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.976(1).xls
# Deleted duplicate: ../data2/enron_clean/lynn_blair_000_1_1.pst.144(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.177(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_ring_000_1_1.pst.166(1).xls
# Deleted duplicate: ../data2/enron_clean/jeff_dasovich_000_1_1_1.pst.28(1).xls
# Deleted duplicate: ../data2/enron_clean/kevin_hyatt_000_1_1.pst.55(1).xls
# Deleted duplicate: ../data2/enron_clean/sara_shackleton_000_1_2.pst.122(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.700(1).xls
# Deleted duplicate: ../data2/enron_clean/a1(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.526(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.940(1).xls
# Deleted duplicate: ../data2/enron_clean/john_hodge_000_1_1.pst.112(1).xls
# Deleted duplicate: ../data2/enron_clean/jim_schwieger_000_1_1.pst.71(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.195(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.222(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_000_1_1_1.pst.324(1).xls
# Deleted duplicate: ../data2/enron_clean/phillip_allen_000_1_1.pst.224(1).xls
# Deleted duplicate: ../data2/enron_clean/richard_sanders_001_1_1_1.pst.5(1).xls
# Deleted duplicate: ../data2/enron_clean/errol_mclaughlin_jr_001_1_1.pst.294(1).xls
# Deleted duplicate: ../data2/enron_clean/don_baughman_000_1_1.pst.219(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.295(1).xls
# Deleted duplicate: ../data2/enron_clean/sara_shackleton_000_1_2.pst.114(1).xls
# Deleted duplicate: ../data2/enron_clean/tracy_geaccone_000_1_1.pst.239(1).xls
# Deleted duplicate: ../data2/enron_clean/sara_shackleton_000_1_2.pst.118(1).xls
# Deleted duplicate: ../data2/enron_clean/lynn_blair_000_1_1.pst.50(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.759(1).xls
# Deleted duplicate: ../data2/enron_clean/darrell_schoolcraft_000_1_1_1.pst.353(1).xls
# Deleted duplicate: ../data2/enron_clean/darron_c_giron_000_1_1_1.pst.328(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.831(1).xls
# Deleted duplicate: ../data2/enron_clean/scott_neal_000_1_1.pst.931(1).xls
# Deleted duplicate: ../data2/enron_clean/lisa_gang_000_1_1.pst.287(1).xls
